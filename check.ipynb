# %%
from eval_m3 import eval_and_plot_m3_robust

df_m3 = eval_and_plot_m3_robust(
    categories=("yearly","quarterly","monthly"),
    n_per_cat=8, pick="random", seed=42, epochs=6,
    tsf_root=r"C:\Users\Admin\Desktop\Hybrid-models-for-TS-processing\M3",
    out_prefix=r"C:\Users\Admin\Desktop\Hybrid-models-for-TS-processing\out\m3_ours",
    wavelet="db4", level=1
)

# сводка
if not df_m3.empty:
    print(df_m3.groupby("category")[[c for c in df_m3.columns if c.endswith("_sMAPE")]]
          .mean(numeric_only=True).round(3))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 3
#       1 from eval_m3 import eval_and_plot_m3_robust
# ----> 3 df_m3 = eval_and_plot_m3_robust(
#       4     categories=("yearly","quarterly","monthly"),
#       5     n_per_cat=8, pick="random", seed=42, epochs=6,
#       6     tsf_root=r"C:\Users\Admin\Desktop\Hybrid-models-for-TS-processing\M3",
#       7     out_prefix=r"C:\Users\Admin\Desktop\Hybrid-models-for-TS-processing\out\m3_ours",
#       8     wavelet="db4", level=1
#       9 )
#      11 # сводка
#      12 if not df_m3.empty:
#
# File c:\Users\Admin\Desktop\Hybrid-models-for-TS-processing\eval_m3.py:44, in eval_and_plot_m3_robust(categories, n_per_cat, pick, seed, epochs, tsf_root, out_prefix, wavelet, level)
#      41 np.random.seed(seed)
#      42 torch.manual_seed(seed)
# ---> 44 ensure_train_tsts_from_tsf(tsf_root)
# ...
